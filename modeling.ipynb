# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr, spearmanr

import itertools
import env
import wrangle
import acquire
import prepare
import split
import exploration as exp
import modeling as md

# %% [markdown]
# ## Wrangle

# %%
zillow, cats, quants  = wrangle.wrangle_zillow()

df = zillow.drop(columns='taxamount')
print(df)
target_var = 'taxvaluedollarcnt'
df.latitude = df.latitude / 1000000
df.longitude = df.longitude /1000000
# Out:
#        parcelid  bedroomcnt  bathroomcnt  sqr_ft  taxvaluedollarcnt  \
# 0      14297519         4.0          3.5  3100.0          1023282.0
# 1      17052889         2.0          1.0  1465.0           464000.0
# 2      14186244         3.0          2.0  1243.0           564778.0
# 3      12177905         4.0          3.0  2376.0           145143.0
# 4      12095076         4.0          3.0  2962.0           773303.0
# ...         ...         ...          ...     ...                ...
# 52437  11000655         2.0          2.0  1286.0           354621.0
# 52438  17239384         4.0          2.0  1612.0            67205.0
# 52439  12773139         3.0          1.0  1032.0            49546.0
# 52440  12826780         3.0          2.0  1762.0           522000.0
# 52441  13083743         3.0          2.0  1050.0           259334.0
#
#        yearbuilt         county    latitude    longitude
# 0         1998.0  orange_county  33634931.0 -117869207.0
# 1         1967.0        ventura  34449266.0 -119281531.0
# 2         1962.0  orange_county  33886168.0 -117823170.0
# 3         1970.0    los_angeles  34245180.0 -118240722.0
# 4         1950.0    los_angeles  34145202.0 -118179824.0
# ...          ...            ...         ...          ...
# 52437     1940.0    los_angeles  34245368.0 -118282383.0
# 52438     1964.0        ventura  34300140.0 -118706327.0
# 52439     1954.0    los_angeles  34040895.0 -118038169.0
# 52440     1955.0    los_angeles  33937685.0 -117996709.0
# 52441     1960.0    los_angeles  34010864.0 -117900894.0
#
# [51119 rows x 9 columns]

# %% [markdown]
# ## Overall Model

# %%
all_counties = md.LRM(df, target_var, county='all')
#baseline
print()
print(f'Baseline train:    ${round(round(all_counties.rmse_train_mean_bl,2), -3)}          Train BL normalized:{all_counties.normalized_rmse_train}')
print(f'Baseline validate: ${round(round(all_counties.rmse_val_mean_bl,2), -3)}       Validate BL normalized:{all_counties.normalized_rmse_val}')

all_counties.x_train_scaled.head()
# Out:
# Baseline train:    $414000.0          Train BL normalized:0.89
# Baseline validate: $417000.0       Validate BL normalized:0.89
#    scaled_bedroomcnt  scaled_bathroomcnt  scaled_sqr_ft  scaled_yearbuilt  \
# 0                0.0                 0.0      -0.032258         -0.142857
# 1                1.0                 1.0       1.223790          0.642857
# 2                0.0                -1.0      -0.591734         -0.392857
# 3                1.0                 1.0       0.876008          0.928571
# 4                0.0                 1.0       0.987903          0.857143
#
#    dist_from_la  dist_from_long_beach  dist_santa_monica  dist_from_malibu  \
# 0      0.660602             -0.303763           0.639060          0.662262
# 1      1.980096              2.281499           0.894339         -0.208093
# 2      0.483456             -0.341801           0.547788          0.613060
# 3      0.013610              0.752180          -0.262595         -0.395752
# 4      0.065350              0.041012           0.365409          0.505612
#
#    dist_from_bel_air  dist_balboa_island  dist_laguna_beach  dist_seal_beach  \
# 0           0.748439           -0.924861          -0.848921        -0.537515
# 1           0.901017            1.719159           1.669648         2.222510
# 2           0.632216           -0.760312          -0.739030        -0.568501
# 3          -0.463421            0.719806           0.707754         0.795377
# 4           0.327095           -0.140311          -0.179081        -0.081590
#
#    dist_simi  dist_ventura  dist_ojai  dist_eleanor  scaled_OC  scaled_ventura
# 0   0.798256      0.739388   0.866301      0.702908        1.0             0.0
# 1  -0.487593     -2.330260  -1.906196     -0.642817        0.0             1.0
# 2   0.711347      0.687555   0.793307      0.641547        1.0             0.0
# 3  -0.764877     -0.672956  -0.719200     -0.595460        0.0             0.0
# 4   0.422241      0.496224   0.516489      0.460756        0.0             0.0

# %%
# default
all_counties.lassolars_regression(use_rfe_features=True)
all_counties.loop_OLS_regression()
all_counties.tweedie(use_rfe_features=True)
all_counties.poly_regression()
all_counties.poly_regression(degree=3)
print()

# %%
# all models up to this point
all_counties.all_models_df()
# Out:
#     model_name county     rmse_train  rmse_validate power alpha  percent_diff  \
# 0          OLS    all  341414.615246  343192.507381    NA    NA         -0.52
# 1          OLS    all  340809.554561  342725.620251    NA    NA         -0.56
# 2          OLS    all  335228.839273  337916.572164    NA    NA         -0.80
# 3          OLS    all  333507.977989  335858.526955    NA    NA         -0.70
# 4          OLS    all  332685.698938  334779.195126    NA    NA         -0.63
# 5          OLS    all  331368.812068  333101.884785    NA    NA         -0.52
# 6          OLS    all  331079.130197  332744.887036    NA    NA         -0.50
# 7          OLS    all  322524.775662  324290.090123    NA    NA         -0.55
# 8          OLS    all  322125.676812  323721.090889    NA    NA         -0.50
# 9          OLS    all  319578.460539  320550.659901    NA    NA         -0.30
# 10         OLS    all  316785.301852  317037.611901    NA    NA         -0.08
# 11         OLS    all  316114.597226  316403.080411    NA    NA         -0.09
# 12         OLS    all  316114.255515  316409.679420    NA    NA         -0.09
# 13         OLS    all  312097.057444  312742.755545    NA    NA         -0.21
# 14         OLS    all  312089.940822  312721.140636    NA    NA         -0.20
# 15         OLS    all  311525.508565  312036.747649    NA    NA         -0.16
# 16         OLS    all  311339.799769  311968.496453    NA    NA         -0.20
# 17         OLS    all  310910.594332  311504.582614    NA    NA         -0.19
# 18  lasso_lars    all  311383.368836  312193.253604    NA     1         -0.26
# 19     tweedie    all  305704.747095  309188.721033     1     0         -1.14
# 20  polynomial    all  279611.366010  284201.397832     0    NA         -1.64
# 21  polynomial    all  262639.577912  835490.770918     0    NA       -218.11
#
#     norm_rmse_train  norm_rmse_validate
# 0            0.7339              0.7339
# 1            0.7326              0.7329
# 2            0.7206              0.7226
# 3            0.7169              0.7182
# 4            0.7151              0.7159
# 5            0.7123              0.7123
# 6            0.7116              0.7116
# 7            0.6933              0.6935
# 8            0.6924              0.6923
# 9            0.6869              0.6855
# 10           0.6809              0.6780
# 11           0.6795              0.6766
# 12           0.6795              0.6766
# 13           0.6708              0.6688
# 14           0.6708              0.6687
# 15           0.6696              0.6673
# 16           0.6692              0.6671
# 17           0.6683              0.6661
# 18           0.6693              0.6676
# 19           0.6571              0.6612
# 20           0.6010              0.6077
# 21           0.5645              1.7866

# %% [markdown]
# ## LA County

# %%
los_angeles = df[df.county=='los_angeles']
los_angeles = md.LRM(los_angeles, target_var, county='la')
print()
print(f'Baseline train: {los_angeles.rmse_train_mean_bl}             Train BL normalized:{los_angeles.normalized_rmse_train}')
print(f'Baseline validate: {los_angeles.rmse_val_mean_bl}       Validate BL normalized:{los_angeles.normalized_rmse_val}')
# Out:
# Baseline train: 417161.1024398403             Train BL normalized:0.97
# Baseline validate: 405392.9903419076       Validate BL normalized:0.96

# %%
los_angeles.lassolars_regression(use_rfe_features=True)
los_angeles.loop_OLS_regression()
los_angeles.tweedie(use_rfe_features=True)
los_angeles.poly_regression()
los_angeles.poly_regression(degree=3)
print()

# %%
los_angeles.all_models_df()
# Out:
#     model_name county     rmse_train  rmse_validate power alpha  percent_diff  \
# 0          OLS     la  356740.281718  352140.844123    NA    NA          1.29
# 1          OLS     la  356331.687845  351657.948043    NA    NA          1.31
# 2          OLS     la  331993.373524  329364.998672    NA    NA          0.79
# 3          OLS     la  331362.318758  328353.331785    NA    NA          0.91
# 4          OLS     la  330383.294533  327929.176320    NA    NA          0.74
# 5          OLS     la  327910.397459  325284.700271    NA    NA          0.80
# 6          OLS     la  325576.173863  323928.841556    NA    NA          0.51
# 7          OLS     la  325459.379328  323991.545901    NA    NA          0.45
# 8          OLS     la  325417.293233  324046.401143    NA    NA          0.42
# 9   lasso_lars     la  325428.813368  323975.868225    NA     1          0.45
# 10     tweedie     la  326224.865235  324848.460856     1     0          0.42
# 11  polynomial     la  301688.120380  299825.537941     0    NA          0.62
# 12  polynomial     la  287609.797729  293553.211994     0    NA         -2.07
#
#     norm_rmse_train  norm_rmse_validate
# 0            0.8298              0.8315
# 1            0.8288              0.8304
# 2            0.7722              0.7778
# 3            0.7707              0.7754
# 4            0.7685              0.7744
# 5            0.7627              0.7681
# 6            0.7573              0.7649
# 7            0.7570              0.7651
# 8            0.7569              0.7652
# 9            0.7569              0.7650
# 10           0.7588              0.7671
# 11           0.7017              0.7080
# 12           0.6690              0.6932

# %% [markdown]
# ## Orange County

# %%
# Initialize subset and create LRM object with baseline metrics
orange_county = df[df.county=='orange_county']
orange_county = md.LRM(orange_county, target_var, county='oc')
print()
print(f'Baseline train RMSE:    ${round(orange_county.rmse_train_mean_bl,2)}          Train BL normalized:{orange_county.normalized_rmse_train}')
print(f'Baseline validate RMSE: ${round(orange_county.rmse_val_mean_bl, 2)}       Validate BL normalized:{orange_county.normalized_rmse_val}')

orange_county.x_train_scaled.head()
# Out:
# Baseline train RMSE:    $419338.44          Train BL normalized:0.76
# Baseline validate RMSE: $433694.14       Validate BL normalized:0.79
#    scaled_bedroomcnt  scaled_bathroomcnt  scaled_sqr_ft  scaled_yearbuilt  \
# 0               -1.0                 0.0       0.854404              0.68
# 1               -1.0                -1.5      -0.431766             -0.84
# 2                0.0                -0.5      -0.565952             -0.28
# 3                0.0                -1.0      -0.649019             -0.72
# 4                0.0                 0.5       0.745778              0.40
#
#    dist_balboa_island  dist_laguna_beach  dist_seal_beach
# 0            0.541502          -0.442197         1.137063
# 1            1.262835           1.147149        -0.027133
# 2           -1.453404          -0.381292        -0.288400
# 3           -0.257209           0.266236        -0.422907
# 4            0.197193          -0.646522         0.964482

# %%
# different regression models
orange_county.lassolars_regression(use_rfe_features=True)
orange_county.loop_OLS_regression()
orange_county.tweedie(use_rfe_features=True)
orange_county.poly_regression()
orange_county.poly_regression(degree=3)
print()

# %%
# models using only orange county
orange_county.all_models_df().head()
# Out:
#   model_name county     rmse_train  rmse_validate power alpha  percent_diff  \
# 0        OLS     oc  330923.388749  332958.519923    NA    NA         -0.61
# 1        OLS     oc  329745.558228  330888.964901    NA    NA         -0.35
# 2        OLS     oc  327382.635448  327098.152545    NA    NA          0.09
# 3        OLS     oc  318991.328587  319195.929946    NA    NA         -0.06
# 4        OLS     oc  315685.247651  316186.757960    NA    NA         -0.16
#
#    norm_rmse_train  norm_rmse_validate
# 0           0.6032              0.6081
# 1           0.6011              0.6043
# 2           0.5968              0.5974
# 3           0.5815              0.5830
# 4           0.5755              0.5775

# %%
orange_county.x_train_scaled.head()
# Out:
#    scaled_bedroomcnt  scaled_bathroomcnt  scaled_sqr_ft  scaled_yearbuilt  \
# 0               -1.0                 0.0       0.854404              0.68
# 1               -1.0                -1.5      -0.431766             -0.84
# 2                0.0                -0.5      -0.565952             -0.28
# 3                0.0                -1.0      -0.649019             -0.72
# 4                0.0                 0.5       0.745778              0.40
#
#    dist_balboa_island  dist_laguna_beach  dist_seal_beach
# 0            0.541502          -0.442197         1.137063
# 1            1.262835           1.147149        -0.027133
# 2           -1.453404          -0.381292        -0.288400
# 3           -0.257209           0.266236        -0.422907
# 4            0.197193          -0.646522         0.964482

# %% [markdown]
# ## Ventura

# %%
ventura = df[df.county=='ventura']
ventura = md.LRM(ventura, target_var, county='vent')
print()
print(f'Baseline train: {ventura.rmse_train_mean_bl}              Train BL normalized:{ventura.normalized_rmse_train}')
print(f'Baseline validate: {ventura.rmse_val_mean_bl}       Validate BL normalized:{ventura.normalized_rmse_val}')
# Out:
# Baseline train: 313827.1058231729              Train BL normalized:0.65
# Baseline validate: 316290.20891438174       Validate BL normalized:0.65

# %%
ventura.lassolars_regression(use_rfe_features=True)
ventura.loop_OLS_regression()
ventura.tweedie(use_rfe_features=True)
ventura.poly_regression()
ventura.poly_regression(degree=3)
print()

# %%
ventura.all_models_df()
# Out:
#     model_name county     rmse_train  rmse_validate power alpha  percent_diff  \
# 0          OLS   vent  224110.923191  217038.794345    NA    NA          3.16
# 1          OLS   vent  223967.928742  217283.686122    NA    NA          2.98
# 2          OLS   vent  222359.059048  215953.737139    NA    NA          2.88
# 3          OLS   vent  218839.528736  211978.767899    NA    NA          3.14
# 4          OLS   vent  218590.360007  212315.884416    NA    NA          2.87
# 5          OLS   vent  218434.561228  212290.905025    NA    NA          2.81
# 6          OLS   vent  218425.732652  212435.947924    NA    NA          2.74
# 7          OLS   vent  215136.010414  209131.082365    NA    NA          2.79
# 8   lasso_lars   vent  215136.508805  209143.146390    NA     1          2.79
# 9      tweedie   vent  207248.117746  199819.600630     1     0          3.58
# 10  polynomial   vent  195747.482321  198404.526431     0    NA         -1.36
# 11  polynomial   vent  177455.341725  232848.378221     0    NA        -31.22
#
#     norm_rmse_train  norm_rmse_validate
# 0            0.4621              0.4480
# 1            0.4619              0.4485
# 2            0.4585              0.4458
# 3            0.4513              0.4375
# 4            0.4508              0.4382
# 5            0.4504              0.4382
# 6            0.4504              0.4385
# 7            0.4436              0.4317
# 8            0.4436              0.4317
# 9            0.4274              0.4125
# 10           0.4037              0.4095
# 11           0.3659              0.4806
